# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, f_oneway, chi2_contingency
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.api import add_constant

# %%
# Load datasets (replace with your file paths or loading methods)
orders = pd.read_csv('datasets/olist_orders_dataset.csv')#
customers = pd.read_csv('datasets/olist_customers_dataset.csv')#
geolocation = pd.read_csv('datasets/olist_geolocation_dataset.csv')
order_items = pd.read_csv('datasets/olist_order_items_dataset.csv')#
products = pd.read_csv('datasets/olist_products_dataset.csv')#
sellers = pd.read_csv('datasets/olist_sellers_dataset.csv')#
payments = pd.read_csv('datasets/olist_order_payments_dataset.csv')#
reviews = pd.read_csv('datasets/olist_order_reviews_dataset.csv')#
product_translation = pd.read_csv('datasets/product_category_name_translation.csv')#

# %%
product_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          7/24/2018 20:41    7/26/2018 3:24
# 2    delivered            8/8/2018 8:38     8/8/2018 8:55
# 3    delivered         11/18/2017 19:28  11/18/2017 19:45
# 4    delivered          2/13/2018 21:18   2/13/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              7/26/2018 14:31                8/7/2018 15:27
# 2               8/8/2018 13:50               8/17/2018 18:06
# 3             11/22/2017 13:39                12/2/2017 0:28
# 4              2/14/2018 19:46               2/16/2018 18:17
#
#   order_estimated_delivery_date
# 0               10/18/2017 0:00
# 1                8/13/2018 0:00
# 2                 9/4/2018 0:00
# 3               12/15/2017 0:00
# 4                2/26/2018 0:00

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0      9/19/2017 9:45   58.90          13.29
# 1      5/3/2017 11:05  239.90          19.93
# 2     1/18/2018 14:48  199.00          17.87
# 3     8/15/2018 10:10   12.99          12.79
# 4     2/13/2017 13:57  199.90          18.14

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN       1/18/2018 0:00
# 1                                                NaN       3/10/2018 0:00
# 2                                                NaN       2/17/2018 0:00
# 3              Recebi bem antes do prazo estipulado.       4/21/2017 0:00
# 4  Parabéns lojas lannister adorei comprar pela I...        3/1/2018 0:00
#
#   review_answer_timestamp
# 0         1/18/2018 21:46
# 1          3/11/2018 3:05
# 2         2/18/2018 14:36
# 3         4/21/2017 22:02
# 4          3/2/2018 10:26

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp order_approved_at  \
# count         99441                    99441             99281
# unique            8                    88789             50462
# top       delivered           8/2/2018 12:06   1/10/2018 10:32
# freq          96478                       28               109
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        61544                         75649
# top                  5/9/2018 15:48                2/1/2018 20:29
# freq                             47                             7
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top                  12/20/2017 0:00
# freq                             522

# %%
reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# Perform the LEFT JOINS step by step

merged_df = pd.merge(
    order_items, products,
    on='product_id',
    how='left'
)

# %%
merged_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0      9/19/2017 9:45   58.90          13.29            cool_stuff
# 1      5/3/2017 11:05  239.90          19.93              pet_shop
# 2     1/18/2018 14:48  199.00          17.87      moveis_decoracao
# 3     8/15/2018 10:10   12.99          12.79            perfumaria
# 4     2/13/2017 13:57  199.90          18.14    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 58.0                       598.0                 4.0
# 1                 56.0                       239.0                 2.0
# 2                 59.0                       695.0                 2.0
# 3                 42.0                       480.0                 1.0
# 4                 59.0                       409.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             650.0               28.0                9.0              14.0
# 1           30000.0               50.0               30.0              40.0
# 2            3050.0               33.0               13.0              33.0
# 3             200.0               16.0               10.0              15.0
# 4            3750.0               35.0               40.0              30.0

# %%
merged_df = pd.merge(
    merged_df, product_translation,
    left_on='product_category_name', right_on='product_category_name',
    how='left'
)

# %%
merged_df = pd.merge(
    merged_df, orders,
    on='order_id',
    how='left'
)

# %%
merged_df = pd.merge(
    merged_df, reviews,
    on='order_id',
    how='left'
)

# %%
merged_df = pd.merge(
    merged_df, payments,
    on='order_id',
    how='left'
)
merged_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0      9/19/2017 9:45   58.90          13.29            cool_stuff
# 1      5/3/2017 11:05  239.90          19.93              pet_shop
# 2     1/18/2018 14:48  199.00          17.87      moveis_decoracao
# 3     8/15/2018 10:10   12.99          12.79            perfumaria
# 4     2/13/2017 13:57  199.90          18.14    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  ...  \
# 0                 58.0                       598.0  ...
# 1                 56.0                       239.0  ...
# 2                 59.0                       695.0  ...
# 3                 42.0                       480.0  ...
# 4                 59.0                       409.0  ...
#
#                           review_id  review_score  review_comment_title  \
# 0  97ca439bc427b48bc1cd7177abe71365           5.0                   NaN
# 1  7b07bacd811c4117b742569b04ce3580           4.0                   NaN
# 2  0c5b33dea94867d1ac402749e5438e8b           5.0                   NaN
# 3  f4028d019cb58564807486a6aaf33817           4.0                   NaN
# 4  940144190dcba6351888cafa43f3a3a5           5.0                   NaN
#
#                               review_comment_message  review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.        9/21/2017 0:00
# 1                                                NaN        5/13/2017 0:00
# 2  Chegou antes do prazo previsto e o produto sur...        1/23/2018 0:00
# 3                                                NaN        8/15/2018 0:00
# 4            Gostei pois veio no prazo determinado .         3/2/2017 0:00
#
#   review_answer_timestamp payment_sequential payment_type  \
# 0         9/22/2017 10:57                1.0  credit_card
# 1         5/15/2017 11:34                1.0  credit_card
# 2         1/23/2018 16:06                1.0  credit_card
# 3         8/15/2018 16:39                1.0  credit_card
# 4          3/3/2017 10:54                1.0  credit_card
#
#   payment_installments payment_value
# 0                  2.0         72.19
# 1                  3.0        259.83
# 2                  5.0        216.87
# 3                  2.0         25.78
# 4                  3.0        218.04
#
# [5 rows x 33 columns]

# %%
merged_df = pd.merge(
    merged_df, customers, 
    on='customer_id',
    how='left'
)
merged_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0      9/19/2017 9:45   58.90          13.29            cool_stuff
# 1      5/3/2017 11:05  239.90          19.93              pet_shop
# 2     1/18/2018 14:48  199.00          17.87      moveis_decoracao
# 3     8/15/2018 10:10   12.99          12.79            perfumaria
# 4     2/13/2017 13:57  199.90          18.14    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  ...  review_creation_date  \
# 0                 58.0                       598.0  ...        9/21/2017 0:00
# 1                 56.0                       239.0  ...        5/13/2017 0:00
# 2                 59.0                       695.0  ...        1/23/2018 0:00
# 3                 42.0                       480.0  ...        8/15/2018 0:00
# 4                 59.0                       409.0  ...         3/2/2017 0:00
#
#    review_answer_timestamp  payment_sequential  payment_type  \
# 0          9/22/2017 10:57                 1.0   credit_card
# 1          5/15/2017 11:34                 1.0   credit_card
# 2          1/23/2018 16:06                 1.0   credit_card
# 3          8/15/2018 16:39                 1.0   credit_card
# 4           3/3/2017 10:54                 1.0   credit_card
#
#    payment_installments payment_value                customer_unique_id  \
# 0                   2.0         72.19  871766c5855e863f6eccc05f988b23cb
# 1                   3.0        259.83  eb28e67c4c0b83846050ddfb8a35d051
# 2                   5.0        216.87  3818d81c6709e39d06b2738a8d3a2474
# 3                   2.0         25.78  af861d436cfc08b2c2ddefd0ba074622
# 4                   3.0        218.04  64b576fb70d441e8f1b2d7d446e483c5
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    28013  campos dos goytacazes             RJ
# 1                    15775        santa fe do sul             SP
# 2                    35661          para de minas             MG
# 3                    12952                atibaia             SP
# 4                    13226        varzea paulista             SP
#
# [5 rows x 37 columns]

# %%
merged_df = pd.merge(
    merged_df, sellers, 
    on='seller_id',
    how='left'
)
merged_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0      9/19/2017 9:45   58.90          13.29            cool_stuff
# 1      5/3/2017 11:05  239.90          19.93              pet_shop
# 2     1/18/2018 14:48  199.00          17.87      moveis_decoracao
# 3     8/15/2018 10:10   12.99          12.79            perfumaria
# 4     2/13/2017 13:57  199.90          18.14    ferramentas_jardim
#
#    product_name_lenght  product_description_lenght  ...  payment_type  \
# 0                 58.0                       598.0  ...   credit_card
# 1                 56.0                       239.0  ...   credit_card
# 2                 59.0                       695.0  ...   credit_card
# 3                 42.0                       480.0  ...   credit_card
# 4                 59.0                       409.0  ...   credit_card
#
#    payment_installments  payment_value                customer_unique_id  \
# 0                   2.0          72.19  871766c5855e863f6eccc05f988b23cb
# 1                   3.0         259.83  eb28e67c4c0b83846050ddfb8a35d051
# 2                   5.0         216.87  3818d81c6709e39d06b2738a8d3a2474
# 3                   2.0          25.78  af861d436cfc08b2c2ddefd0ba074622
# 4                   3.0         218.04  64b576fb70d441e8f1b2d7d446e483c5
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     28013  campos dos goytacazes             RJ
# 1                     15775        santa fe do sul             SP
# 2                     35661          para de minas             MG
# 3                     12952                atibaia             SP
# 4                     13226        varzea paulista             SP
#
#   seller_zip_code_prefix    seller_city seller_state
# 0                  27277  volta redonda           SP
# 1                   3471      sao paulo           SP
# 2                  37564  borda da mata           MG
# 3                  14403         franca           SP
# 4                  87900         loanda           PR
#
# [5 rows x 40 columns]

# %%
merged_df.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value',
#        'customer_unique_id', 'customer_zip_code_prefix', 'customer_city',
#        'customer_state', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state'],
#       dtype='object')

# %%
merged_df.shape
# Out:
# (118310, 40)

# %%
merged_df.to_csv("Final_dataset.csv",index=False)
